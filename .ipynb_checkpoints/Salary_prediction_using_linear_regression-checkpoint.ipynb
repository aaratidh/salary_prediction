# %%
import numpy as np 
import matplotlib.pyplot as ptl 
import pandas as pd

# %%
data = pd.read_csv('salary.csv')

# %%
data
# Out:
#    experience  test_score  interview_score  Salary
# 0         NaN         8.0              8.0   50000
# 1         NaN         5.0              4.0   22000
# 2       three         6.0              5.0   30000
# 3        five         9.0              9.0   55000
# 4         six         3.0              5.0   13000
# 5         NaN         2.0              1.0    9000
# 6         ten         8.0              6.0   48000
# 7         one         1.0              2.0     500
# 8     fifteen         9.0              9.0   60000
# 9    thirteen         7.5              7.5   45000
# 10        ten         NaN              5.0   25000
# 11        NaN         1.0              1.0     500
# 12        one         3.0              6.0   25000
# 13       four         5.0              4.0   36000
# 14        six         5.0              NaN    8000
# 15     eleven         9.0              8.0   55000
# 16     twelve         9.0              9.0   58000
# ...

# %%
data.dtypes
# Out:
# experience          object
# test_score         float64
# interview_score    float64
# Salary               int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split 
from pattern.en import number

# %%
#replacing Nan with the O value
data =data.replace(np.nan,0)
data["experience"]
# Out:
# 0            0
# 1            0
# 2        three
# 3         five
# 4          six
# 5            0
# 6          ten
# 7          one
# 8      fifteen
# 9     thirteen
# 10         ten
# 11           0
# 12         one
# 13        four
# 14         six
# 15      eleven
# 16      twelve
# 17           0
# 18       three
# 19        five
# Name: experience, dtype: object

# %%
#convert non-numerical variable into numercal value 
exp_colm = data["experience"]
for i in range  (0,len(exp_colm)):

    if type(exp_colm[i])!= int:
        exp_colm[i] = number(exp_colm[i])
# Out:
# <ipython-input-7-8a4e9d9259c5>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_colm[i] = number(exp_colm[i])

# %%
#adding updated value in datframe
data['experience']=exp_colm

# %%
data['experience']
# Out:
# 0      0
# 1      0
# 2      3
# 3      5
# 4      6
# 5      0
# 6     10
# 7      1
# 8     15
# 9     13
# 10    10
# 11     0
# 12     1
# 13     4
# 14     6
# 15    11
# 16    12
# 17     0
# 18     3
# 19     5
# Name: experience, dtype: object

# %%
#now data is ready for machine learning
data
# Out:
#    experience  test_score  interview_score  Salary
# 0           0         8.0              8.0   50000
# 1           0         5.0              4.0   22000
# 2           3         6.0              5.0   30000
# 3           5         9.0              9.0   55000
# 4           6         3.0              5.0   13000
# 5           0         2.0              1.0    9000
# 6          10         8.0              6.0   48000
# 7           1         1.0              2.0     500
# 8          15         9.0              9.0   60000
# 9          13         7.5              7.5   45000
# 10         10         0.0              5.0   25000
# 11          0         1.0              1.0     500
# 12          1         3.0              6.0   25000
# 13          4         5.0              4.0   36000
# 14          6         5.0              0.0    8000
# 15         11         9.0              8.0   55000
# 16         12         9.0              9.0   58000
# ...

# %%
#identifying the relation between the data 
cormat = data.corr()

# %%
cormat
# Out:
#                  test_score  interview_score    Salary
# test_score         1.000000         0.721538  0.890901
# interview_score    0.721538         1.000000  0.877587
# Salary             0.890901         0.877587  1.000000

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
fig = plt.figure(figsize = (12, 12 ))
sns.heatmap(cormat, vmax = .8, square = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# see there is a strong connection between interviw score and salary, similary same for test score and salery but there is not relation between tesscore and interview score so it is better to keep both of the score column

# %%
Y = data["Salary"]
X = data.loc[:, data.columns != 'Salary']


plt.scatter(data["test_score"],Y,color='blue')
plt.xlabel('test score ')
plt.ylabel('Salary')
plt.title('Salary Prediction Curves')
plt.show()

# %%
Y = data["Salary"]
X = data.loc[:, data.columns != 'Salary']


plt.scatter(data["experience"],Y,color='blue')
plt.xlabel('Years of experience ')
plt.ylabel('Salary')
plt.title('Salary Prediction Curves')
plt.show()

# %% [markdown]
# It look like there is more liner relation between th test score and salary prediction than of the test score

# %%
#using seaborn library we fidn out hte relation between the columns and the target varaible 
import seaborn as sb
sb.pairplot(data)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_test_pred = model.predict(X_test)
Y_test_pred
# Out:
# array([22871.55689658, 24250.48440298, 27132.47228429, 41959.60604808])

# %%
from sklearn.metrics import explained_variance_score
explained_variance_score(Y_test, Y_test_pred)
#print('Accuracy score of test data : ', test_data_accuracy)
# Out:
# 0.704684029816776

# %% [markdown]
# @ Thankyou
